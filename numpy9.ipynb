# %% [markdown]
# In simple terms, vectorization is a way to perform operations on entire arrays or large chunks of data at once, rather than one element at a time using loops. This approach is efficient because it uses highly optimized, low-level code underneath, making it much faster than traditional looping in Python.
#
# https://youtu.be/BR3Qx9AVHZE?feature=shared

# %% [markdown]
# WORKING WITH MATH FORMULAS

# %%
import numpy as np

# %%
import numpy as np

def sigmoid(array):
    return 1 / (1 + np.exp(-array))

def sme(actual,predict):
  return np.mean((actual-predict)**2)
def ll()
# Out:
# [[0.73105858 0.88079708 0.95257413]
#  [0.98201379 0.99330715 0.99752738]
#  [0.99908895 0.99966465 0.99987661]]

# %% [markdown]
# DEALING WITH MISSING VALUES
#
# in data analysis sometimes some info are opetional so some send and some not, but we have to analyzie the data , sp there is a term where the the data is missing or not present nan , so it make diifculty when analyzing the data , so we have to deal with missing value in numpy we use boolean masking tech to deal with it

# %%
a = np.array([1,2,4,np.nan,5,6,7,8])
mask = ~np.isnan(a) #values which are not Nan
a[mask]
# Out:
# array([1., 2., 4., 5., 6., 7., 8.])

# %% [markdown]
# PLOTTING GRAPHS

# %%
import matplotlib.pyplot as plt
x = np.linspace(-10,10,100)
y = x
plt.plot(x,y)

# %%
x = np.linspace(-10,10,100)
y = x**2
plt.plot(y)

# %%
x = np.linspace(-10,10,100)
y =x*(np.log(x))
plt.plot(x,y)
# Out:
# <ipython-input-16-1743291731d9>:2: RuntimeWarning: invalid value encountered in log
#   y =x*(np.log(x))

# %%
x = np.linspace(-10,10,100)
y = np.sin(x)
plt.plot(x,y)

# %%
x =np.linspace(-10,10,100)
y  = 1 / (1+np.exp(-x))
plt.plot(x,y)
